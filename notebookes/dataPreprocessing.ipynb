# %% [markdown]
# # Data Preprocessing For Supermarket Sales Prediction
# Super Market Sales Forecasting is a data-driven project designed to predict future sales performance using historical sales data, seasonal trends, and customer purchasing patterns.
#
# ## Libraries
# - numpy and pandas
# - matplotlib and seaborn
# - Pathlib
# - sci-kit learn
# - warnings
#
# ## Tasks
# 1. Import Libraries
# 2. Load Dataset
# 3. Explore Dataset
# 4. [Sanity Check](#sanity-checks)
#     - Remove redundant columns
#     - Standardize column names
#     - Duplicate check
#     - Missing value check
# 5. Exploratory Data Analysis
#     - [Univariate Analysis](#univariate-analysis)
#     - [Bivariate Analysis](#bivariate-analysis)
#     - [Multivariate Analysis](#multivariate-analysis)
# 6. Handling Missing Value
# 8. Feature Engineering
# 9. Save Artifacts

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.model_selection import train_test_split, StratifiedKFold
from category_encoders import TargetEncoder
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from pathlib import Path
import joblib
import pickle

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
# reading filepath of raw dataset
train_path = Path.cwd().parent / "data" / "Train.csv"
test_path = Path(r"../data/Test.csv")

# %%
# read files
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %% [markdown]
# ## Verify Data Load

# %%
print("Train DataFrame Shape:", train_df.shape)
train_df.head()
# Out:
# Train DataFrame Shape: (8523, 12)
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print("Test DataFrame Shape:", test_df.shape)
test_df.head()
# Out:
# Test DataFrame Shape: (5681, 11)
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# concatenate train and test data for preprocessing
main_df = pd.concat([train_df, test_df], ignore_index=True)

# %%
print("Shape of Concatenated DataFrame:", main_df.shape)
main_df.head()
# Out:
# Shape of Concatenated DataFrame: (14204, 12)
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# # Sanity Checks

# %%
# quick overview of data
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
# dataset description
main_df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# columns names
main_df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# drop redundant columns
main_df.drop(columns=['Item_Identifier', 'Outlet_Identifier'], inplace=True)

main_df.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# rename column names
main_df.rename(columns={
    "Item_Weight" : "ItemWeight",
    "Item_Fat_Content" : "FatContent",
    "Item_Visibility" : "Visibility",
    "Item_Type" : "ItemType",
    "Item_MRP" : "MRP",
    "Outlet_Establishment_Year" : "OutletEstablishmentYear",
    "Outlet_Size" : "OutletSize",
    "Outlet_Location_Type" : "LocationType",
    "Outlet_Type" : "OutletType",
    "Item_Outlet_Sales" : "OutletSales"
}, inplace=True)

# remove leading and trailing spaces from column names
main_df.columns = main_df.columns.str.strip()

main_df.columns
# Out:
# Index(['ItemWeight', 'FatContent', 'Visibility', 'ItemType', 'MRP',
#        'OutletEstablishmentYear', 'OutletSize', 'LocationType', 'OutletType',
#        'OutletSales'],
#       dtype='object')

# %%
# check duplicates
main_df.duplicated().sum()
# Out:
# 0

# %%
# check missing values
main_df.isnull().sum()
# Out:
# ItemWeight                 2439
# FatContent                    0
# Visibility                    0
# ItemType                      0
# MRP                           0
# OutletEstablishmentYear       0
# OutletSize                 4016
# LocationType                  0
# OutletType                    0
# OutletSales                5681
# dtype: int64

# %%
# missing percantage
main_df.isnull().sum() / main_df.shape[0] * 100
# Out:
# ItemWeight                 17.171219
# FatContent                  0.000000
# Visibility                  0.000000
# ItemType                    0.000000
# MRP                         0.000000
# OutletEstablishmentYear     0.000000
# OutletSize                 28.273726
# LocationType                0.000000
# OutletType                  0.000000
# OutletSales                39.995776
# dtype: float64

# %% [markdown]
# **NOTE:** `OutletSales` is our target variable, and ~40% missing is a serious issue. Because rows with missing `OutletSales` cannot contribute to training. So we can remove rows which will leaves us with ~60% of the data (still likely sufficient for modeling), and ensures our training set has valid labels.

# %%
# drop missing rows from targeted variables
main_df = main_df.dropna(subset=['OutletSales'])

# %% [markdown]
# ## Dataset After Sanity Check

# %%
# dataframe shape
main_df.shape
# Out:
# (8523, 10)

# %%
# columns
main_df.columns
# Out:
# Index(['ItemWeight', 'FatContent', 'Visibility', 'ItemType', 'MRP',
#        'OutletEstablishmentYear', 'OutletSize', 'LocationType', 'OutletType',
#        'OutletSales'],
#       dtype='object')

# %%
# missing value status
main_df.isnull().sum()
# Out:
# ItemWeight                 1463
# FatContent                    0
# Visibility                    0
# ItemType                      0
# MRP                           0
# OutletEstablishmentYear       0
# OutletSize                 2410
# LocationType                  0
# OutletType                    0
# OutletSales                   0
# dtype: int64

# %%
# dataset preview
main_df.head()
# Out:
#    ItemWeight FatContent  Visibility               ItemType       MRP  \
# 0        9.30    Low Fat    0.016047                  Dairy  249.8092
# 1        5.92    Regular    0.019278            Soft Drinks   48.2692
# 2       17.50    Low Fat    0.016760                   Meat  141.6180
# 3       19.20    Regular    0.000000  Fruits and Vegetables  182.0950
# 4        8.93    Low Fat    0.000000              Household   53.8614
#
#    OutletEstablishmentYear OutletSize LocationType         OutletType  \
# 0                     1999     Medium       Tier 1  Supermarket Type1
# 1                     2009     Medium       Tier 3  Supermarket Type2
# 2                     1999     Medium       Tier 1  Supermarket Type1
# 3                     1998        NaN       Tier 3      Grocery Store
# 4                     1987       High       Tier 3  Supermarket Type1
#
#    OutletSales
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052

# %% [markdown]
# # Exploratory Data Analysis
# - Univariate Analysis
#     - Countplots for categrocial predictor
#     - Histplot for Data Distribution
#     - Boxplot for outliers check

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### counplots for categorical predictor

# %%
cat_ft = main_df.select_dtypes(include='object').columns
print("Number of Categorical Features:", len(cat_ft))
print("Categorical Features:", cat_ft)
# Out:
# Number of Categorical Features: 5
# Categorical Features: Index(['FatContent', 'ItemType', 'OutletSize', 'LocationType', 'OutletType'], dtype='object')

# %%
# columns for unique value distribution
categorical_cols = cat_ft.to_list() + ['OutletEstablishmentYear']

# set the number of rows and columns for the grid
rows, cols = 3, 3

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=5.0)
fig.suptitle('Countplots For Categorical Predictors', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(categorical_cols):
    row_pos = i // cols
    col_pos = i % cols
    ax = axes[row_pos, col_pos]

    sns.countplot(data=main_df, x=col, ax=ax, palette="mako")
    ax.set_title(f"{col} Distribution")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=25, ha='right', rotation_mode='anchor')

# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])


plt.subplots_adjust(hspace=0.6)
plt.show()

# %% [markdown]
# #### Observations & Insights from Each Plot
#
# 1. `FatContent` Distribution
#
# Obeservations:
# - Dominant categories: “Low Fat” (~5000), “Regular” (~3000)
# - Rare categories: “low fat”, “LF”, “reg” (likely typos or inconsistent encoding)
#
# Decision / Action:
# - Standardize labels
#
# 2. `ItemType` Distribution
#
# Observations:
# - Highly imbalanced — some categories like “Household”, “Fruits and Vegetables”, “Snack Foods” are frequent.
# - Others like “Seafood”, “Breakfast”, “Health and Hygiene” are very rare (<200).
#
# Decision / Action:
# - Group rare categories into an “Others” bucket to reduce noise and overfitting.
#
# 3. `OutletSize` Distribution
#
# Observations:
# - Medium: ~2700
# - Small: ~2400
# - High: ~900
#
# Decision / Action:
# - Keep as-is. No extreme imbalance.
# - If using one-hot encoding, ensure you handle “Medium” as reference if needed (but not critical).
# - Consider if “High” outlets behave differently — might be worth exploring in bivariate analysis.
#
# 4. `LocationType` Distribution
#
# Observations:
# - Tier 3 > Tier 2 > Tier 1 which is roughly balanced but Tier 3 has most data.
#
# Decision / Action:
# - No action needed. All levels are well-represented.
# - In modeling, this variable may help capture regional demand differences.
#
# 5. `OutletType` Distribution
#
# Observations:
# - Supermarket Type1: ~5500 (dominant)
# - Grocery Store: ~1100
# - Supermarket Type2/3: ~900–1000 each
#
# Decision / Action:
# - Leave as-is since “Grocery Store” is distinct and meaningful.
#
# 6. OutletEstablishmentYear
# - Peaks in 1985, then drops, with smaller peaks around 1997–2009.
# - Not evenly distributed — suggests outlets opened in waves.
#
# Decision / Action:
# - Convert to `OutletAge` = 2025 - OutletEstablishmentYear will be better for modeling than raw year.

# %% [markdown]
# ### Action according to analysis

# %%
# Standardize labels
main_df['FatContent'] = main_df['FatContent'].replace({
    'low fat': 'Low Fat',
    'LF': 'Low Fat',
    'reg': 'Regular'
})

# %%
# fix misleading data issue
main_df['OutletAge'] = 2025 - main_df['OutletEstablishmentYear']

# drop 'OutletEstablishmentYear' column as it's now redundant
main_df.drop('OutletEstablishmentYear', axis=1, inplace=True)

# %% [markdown]
# ### histplot for indentifying data distribution

# %%
num_ft = main_df.select_dtypes(include='number').columns
print("Number of Categorical Features:", len(num_ft))
print("Categorical Features:", num_ft)
# Out:
# Number of Categorical Features: 5
# Categorical Features: Index(['ItemWeight', 'Visibility', 'MRP', 'OutletSales', 'OutletAge'], dtype='object')

# %%
# exclude the binary columns
numerical_cols = [col for col in num_ft if col != 'OutletAge']

# set grid size dynamically
# ceil division for rows
rows = (len(numerical_cols) + 1) // 2
cols = 2

# create subplots
# flatten to 1D for easier indexing
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
axes = axes.flatten()

fig.tight_layout(pad=5.0)
fig.suptitle('Histpots for Numerical Data Distribution', fontsize=15, y=1.01)

# plot histograms
for i, col in enumerate(numerical_cols):
    sns.histplot(data=main_df, x=col, ax=axes[i], palette="mako", kde=True)
    axes[i].set_title(f"{col} Distribution")

# remove unused subplots
for j in range(len(numerical_cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(pad=3.0, h_pad=3, w_pad=5)
plt.show()

# %% [markdown]
# #### Observations & Insights from Each Plot
#
# 1. `ItemWeight` Distribution
#
# Obeservations:
# - Shape: Roughly normal / bell-shaped, centered around 8–18.
# - No extreme outliers or heavy skewness.
# - Slight dip in the middle (around 12–14), but overall smooth.
#
# Decision / Action:
# - No transformation needed. It’s already well-behaved.
# - Keep as-is for modeling.
# - If using tree-based models (e.g., Random Forest, XGBoost), no scaling required.
# - For linear models, consider standardization if other features are scaled.
#
# 2. `Visibility` Distribution
#
# Observations:
# - Highly right-skewed — most items have very low visibility (<0.1), with a long tail.
# - Many items have zero or near-zero visibility (as seen in your sample data).
# - This is common in retail: most products are not prominently displayed.
#
# Zero values may be true zeros (not displayed) or missing data coded as zero.
#
# Decision / Action:
# - Handle Zeros
# - Log Transform
#
# 3. `MRP` Distribution
#
# Observations:
# - Multi-modal — peaks around ₹50, ₹100, ₹150, ₹200, ₹250.
# - This suggests price bands — retailers likely price items at round numbers.
#
# Decision / Action:
# - Keep as-is. No extreme imbalance.
# - If using one-hot encoding, ensure you handle “Medium” as reference if needed (but not critical).
# - Consider if “High” outlets behave differently — might be worth exploring in bivariate analysis.
#
# 4. `OutletSales` Distribution
#
# Observations:
# - Strongly right-skewed — most sales are low, few are very high (up to ~12,000).
# - Classic retail sales pattern — many low-volume items, few high-volume “hero” products.
#
# Decision / Action:
# - Log Transform Target
# - Use RMSE on Log Scale

# %% [markdown]
# ### Action according to analysis

# %%
# Log-transform target features to reduce skewness
main_df['OutletSales_log'] = np.log(main_df['OutletSales'])

# %%
# Log-transform Visibility (handle zeros safely)
main_df['Visibility_log'] = np.log(main_df['Visibility'] + 1)

# %%
# Re-plot histograms for specific columns
numerical_cols = ['OutletSales_log', 'Visibility_log']

# create subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
axes = axes.flatten()

fig.suptitle('Histograms for Numerical Data Distribution', fontsize=15, y=1.01)

# plot histograms
for i, col in enumerate(numerical_cols):
    sns.histplot(data=main_df, x=col, ax=axes[i], kde=True)
    axes[i].set_title(f"{col} Distribution")
    


plt.tight_layout(pad=3.0, h_pad=3, w_pad=5)
plt.show()

# %% [markdown]
# #### Observations & Insights from Each Plot
#
# 1. `OutletSales_log` Distribution
#
# Obeservations:
# - Shape: Now approximately normal / bell-shaped, centered around 7.5–8.0.
# - Skewness reduced: The long right tail (high sales outliers) is compressed.
# - Outliers still present: A few very low values (log ~4–5) — these represent items with extremely low sales (e.g., ₹50–150).
#
# 2. `Visibility_log` Distribution
#
# Observations:
# - Shape: Still slightly right-skewed, but much improved from raw Visibility.
# - Peaks around 0.02–0.05 (i.e., original visibility ~1.02–1.05 after exp).
# - Many items have low log-visibility (close to 0), which corresponds to near-zero raw visibility.

# %% [markdown]
# ### Boxplot for Detecting Outliers

# %%
# Column to check
numerical_cols = ['ItemWeight', 'MRP', 'OutletAge', 'Visibility_log', 'OutletSales_log']

# set the number of rows and columns for the grid
rows, cols = 2, 3

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=5.0)
fig.suptitle('Boxplot for Outliers Detection', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(numerical_cols):
    row_pos = i // cols
    col_pos = i % cols
    ax = axes[row_pos, col_pos]
    sns.boxplot(data=main_df, x=col, ax=ax, palette="mako")
    ax.set_title(f"Boxplot of {col}")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=25, ha='right', rotation_mode='anchor')

# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])

plt.show()

# %% [markdown]
# #### Observations & Insights from Each Plot
#
# 1.  Boxplot of `ItemWeight`
#
# Obeservations:
# - IQR: ~9 to 17 → most items weigh between 9–17 kg.
# - Whiskers: ~5 to 21 → reasonable range for retail items.
# - No visible outliers → clean distribution.
#
# Decision / Action:
# - No action needed. Data is well-behaved. Keep as-is.
#
# 2. Boxplot of `MRP`
#
# Observations:
# - IQR: ~100 to 200 → most items priced between ₹100–200.
# - Whiskers: ~50 to 260 → some higher-priced items.
# - No extreme outliers → suggests pricing is consistent.
#
# Decision / Action:
# -  No action needed. No need to cap or transform unless bivariate analysis shows non-linear relationship with sales.
#
# 3. Boxplot of `OutletAge`
#
# Observations:
# - IQR: ~22 to 38 → most outlets are 22–38 years old.
# - Whiskers: ~16 to 40 → no extreme outliers.
# - Slight left skew (median closer to upper quartile) → more newer outlets than very old ones.
#
# Decision / Action:
# - No action needed. Age is a meaningful continuous variable. Consider binning later if bivariate analysis suggests non-linear effect.
#
# 4. Boxplot of `Visibility_log`
#
# Observations:
# - IQR: Very narrow — centered around 0.05 to 0.10.
# - Many points near 0 → corresponds to raw visibility = 0 (not displayed).
# - Few high values → some items have higher visibility.
# - Outliers: A few dots beyond whiskers at ~0.25–0.30 → these are items with relatively high visibility.
#
# Decision / Action:
# - Create a binary flag
#
# 5. Boxplot of `OutletSales_log`
#
# Observations:
# - IQR: ~7.0 to 8.0 → median sales ≈ ₹1000–3000.
# - Whiskers: ~5.0 to 9.0 → sales range from ₹150 to ₹8000+.
# - Many points beyond whiskers → especially on the lower end (log < 5.5).
#
# Decision / Action:
# - Do NOT remove outliers

# %% [markdown]
# ### Action according to analysis

# %%
# Create binary flag for zero visibility
main_df['IsVisibile'] = (main_df['Visibility'] != 0).astype(int)

# %%
# dataset after univariate analysis
main_df.head()
# Out:
#    ItemWeight FatContent  Visibility               ItemType       MRP  \
# 0        9.30    Low Fat    0.016047                  Dairy  249.8092
# 1        5.92    Regular    0.019278            Soft Drinks   48.2692
# 2       17.50    Low Fat    0.016760                   Meat  141.6180
# 3       19.20    Regular    0.000000  Fruits and Vegetables  182.0950
# 4        8.93    Low Fat    0.000000              Household   53.8614
#
#   OutletSize LocationType         OutletType  OutletSales  OutletAge  \
# 0     Medium       Tier 1  Supermarket Type1    3735.1380         26
# 1     Medium       Tier 3  Supermarket Type2     443.4228         16
# 2     Medium       Tier 1  Supermarket Type1    2097.2700         26
# 3        NaN       Tier 3      Grocery Store     732.3800         27
# 4       High       Tier 3  Supermarket Type1     994.7052         38
#
#    OutletSales_log  Visibility_log  IsVisibile
# 0         8.225540        0.015920           1
# ...

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Boxplot - Categorical Features vs OutletSales_log

# %%
# Column to check
categorical_cols = ['FatContent', 'ItemType', 'OutletSize', 'LocationType', 'OutletType', 'IsVisibile']

# set the number of rows and columns for the grid
rows, cols = 2, 3

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=5.0)
fig.suptitle('Boxplot for Categorical Features vs OutletSales_log', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(categorical_cols):
    row_pos = i // cols
    col_pos = i % cols
    ax = axes[row_pos, col_pos]
    
    sns.boxplot(data=main_df, x=col, y='OutletSales_log', ax=ax)
    ax.set_title(f"OutletSales_log vs {col}")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=25, ha='right', rotation_mode='anchor')


# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])


plt.tight_layout(pad=3.0, h_pad=3, w_pad=5)
plt.show()

# %% [markdown]
# #### Analysis & Insights from Each Plot
#
# 1. `OutletSales_log vs FatContent`
#
# Obeservations:
# - Median sales: Almost identical for “Low Fat” and “Regular”.
# - Spread: Similar IQR and whiskers.
# - Outliers: Both have low-sales outliers (log < 5).
#
# Insight:
# - `FatContent` has no strong predictive power on sales — likely not useful for modeling.
#
# 2. `OutletSales_log vs ItemType`
#
# Observations:
# - High variation: Some categories (e.g., “Dairy”, “Baking Goods”) have higher median sales; others (e.g., “Seafood”, “Starchy Foods”) lower.
# - Many outliers: Especially for “Seafood”, “Others”, “Breakfast” — some items sell very high/low.
# - Rare categories: “Seafood”, “Breakfast”, “Health and Hygiene” have few data points.
#
# Insight:
# - `ItemType` is highly predictive — but many categories are rare and noisy
#
# 3. `OutletSales_log vs OutletSize`
#
# Observations:
# - Medium: Highest median sales (~7.6), tight IQR.
# - High: Slightly lower median (~7.5), similar spread.
# - Small: Lower median (~7.3), more outliers on low end.
#
# Insight:
# - Outlet size matters — larger stores tend to have higher sales.
#
# 4. `OutletSales_log vs LocationType`
#
# Observations:
# - Tier 1 & Tier 3: Similar median (~7.5), slightly wider IQR for Tier 3.
# - Tier 2: Lower median (~7.3), more low-sales outliers.
#
# Insight:
# - Location type has moderate predictive power — Tier 2 may be less affluent or have lower foot traffic.
#
# 5. `OutletSales_log vs OutletType`
#
# Observations:
# - Supermarket Type1: Highest median (~7.6), tight IQR.
# - Supermarket Type2: Slightly lower (~7.5).
# - Grocery Store: Much lower median (~5.8), wide IQR.
# - Supermarket Type3: High median (~8.0), but fewer samples
#
# Insight:
# - Outlet type is very predictive — Grocery Stores sell much less than Supermarkets.
#
# 6. `OutletSales_log vs IsVisibile`
# - IsVisibile = 0 (not visible): Lower median (~7.0), many low-sales outliers.
# - IsVisibile = 1 (visible): Higher median (~7.5), tighter IQR.
#
# Insight:
# - Visibility has a clear positive effect on sales — items on display sell more.

# %% [markdown]
# ### Action according to analysis

# %%
# group rare items into others and categories with < 300 samples
item_types_counts = main_df['ItemType'].value_counts()
rare_item_types = item_types_counts[item_types_counts < 300].index.tolist()
main_df['ItemType'] = main_df['ItemType'].replace(rare_item_types, 'Others')

# %%
print("ItemType after grouping rare categories:")
print(main_df['ItemType'].value_counts().sort_values(ascending=False))
# Out:
# ItemType after grouping rare categories:
# ItemType
# Fruits and Vegetables    1232
# Snack Foods              1200
# Others                    956
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Name: count, dtype: int64

# %%
# impute missing outlet size using mode per outlet type
main_df['OutletSize'] = main_df.groupby('OutletType')['OutletSize'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else 'Medium'))

# %%
print("OutletSize after imputation:")
print(main_df['OutletSize'].value_counts(dropna=False))
# Out:
# OutletSize after imputation:
# OutletSize
# Small     4798
# Medium    2793
# High       932
# Name: count, dtype: int64

# %%
# Verify no missing values remain in key columns
print("Missing values in key columns:")
print(main_df[['OutletSize', 'ItemType']].isnull().sum())
# Out:
# Missing values in key columns:
# OutletSize    0
# ItemType      0
# dtype: int64

# %% [markdown]
# ### Scatterplot - Numerical Features vs OutletSales_log

# %%
# Column to find relations
numerical_cols = ['MRP', 'ItemWeight', 'OutletAge', 'Visibility_log']

# set the number of rows and columns for the grid
rows, cols = 2, 2

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=5.0)
fig.suptitle('Scatterplot for Numerical Features vs OutletSales_log', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(numerical_cols):
    row_pos = i // cols
    col_pos = i % cols
    ax = axes[row_pos, col_pos]
    
    sns.regplot(data=main_df, x=col, y='OutletSales_log', ax=ax, scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
    ax.set_title(f"OutletSales_log vs {col}")


# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])


plt.tight_layout(pad=3.0, h_pad=3, w_pad=5)
plt.show()

# %% [markdown]
# #### Analysis & Insights from Each Plot
#
# 1. `OutletSales_log vs MRP`
#
# Obeservations:
# - Clear positive trend: As MRP increases, sales tend to increase — especially at lower MRP.
# - Clustering: Sales are concentrated around certain MRP bands (e.g., 50, 100, 150).
# - Saturation: At higher MRP (>200), sales don’t increase much — may indicate price sensitivity.
#
# Insight:
# - `MRP` has a non-linear relationship with sales — strong signal.
#
# 2. `OutletSales_log vs ItemWeight`
#
# Observations:
# - No clear pattern: Points are scattered randomly — no visible correlation.
# - Some low-weight items have high sales, some high-weight items have low sales.
#
# Insight:
# - `IteWeight` has little to no predictive power on sales
#
# 3. `OutletSales_log vs OutletAge`
#
# Observations:
# - No clear trend: Older outlets don’t consistently sell more or less.
# - Slight clustering around age 25–35, but sales vary widely within each age group.
#
# Insight:
# - `OutletAge` is not strongly predictive — may be redundant with other features
#
# 4. `OutletSales_log vs Visibility_log`
#
# Observations:
# - Weak positive trend: Higher visibility tends to correlate with higher sales.
# - Many points clustered near zero visibility (log=0) with low sales — confirms your IsVisibile flag is useful.
# - A few high-visibility items have very high sales.
#
# Insight:
# - `Visibility` matters, but the relationship is weak and noisy — best captured by your binary flag.

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Pairplot for Quick Overview

# %%
# relevant numerical columns
pair_features = ['MRP', 'Visibility_log', 'ItemWeight', 'OutletSales_log']

# copy original dataset
temp_df = main_df.copy()

# handle potential missing values in numerical columns for pairplot
pair_plot = temp_df.dropna(subset=pair_features + ['OutletType']).copy()

if not pair_plot.empty:
    # create pairplot
    sns.pairplot(data=pair_plot,
                vars=pair_features,
                hue='OutletType',
                diag_kind="kde", plot_kws={"palette": "mako"})

    
    plt.suptitle('Pair Plot of Numerical Features by OutletType', y=1.02)
    plt.show()

# %% [markdown]
# #### Analysis & Insights from Each Plot
#
# 1. `Diagonal (Distributions by OutletType)`
#
# Obeservations:
# - `MRP`: All types have similar price distributions — no major difference.
# - `Visibility_log`: Grocery Stores (green) have more items with zero visibility (leftmost peak at 0) — confirms they display fewer items.
# - `OutletAge`: Supermarkets are older on average than Grocery Stores.
# - `ItemWeight`: No strong differences across types.
# - `OutletSales_log`: Grocery Stores (green) have lower median sales — consistent with earlier boxplots.
#
# Insight:
# - Grocery Stores are distinct: lower sales, more zero-visibility items, younger stores.
#
# 2. `Off-Diagonal (Scatter Plots)`
#
# Observations:
# - A. `MRP` vs `OutletSales_log`
#     - All types show positive trend — higher MRP → higher sales.
#     - Grocery Stores (green) have weaker correlation — maybe less price-sensitive or fewer premium items.
# - B. `Visibility_log` vs `OutletSales_log`
#     - Weak positive trend — visible items sell more.
#     - Grocery Stores again show more zero-visibility items and lower sales.
# - C. `ItemWeight` vs `OutletSales_log`
#     - No discernible relationship — confirms earlier scatter plot.

# %% [markdown]
# ### Scatterplot for Feature Influence Relationship

# %%
# define UNIQUE and meaningful pairs for feature influence analysis
scatter_pairs = [
    ('MRP', 'OutletSales_log'),                     # Strongest signal
    ('Visibility_log', 'OutletSales_log'),          # Moderate signal
    ('ItemWeight', 'OutletSales_log')               # For completeness
]

# set up subplot grid
n_plots = len(scatter_pairs)
cols = 2
rows = (n_plots + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
axes = axes.flatten() if n_plots > 1 else [axes]

fig.suptitle('Scatter Plots for Numerical Features vs OutletSales_log by OutletType', fontsize=16, y=0.98)
plt.tight_layout(pad=5.0)

# Plot each scatterplot
for i, (col_x, col_y) in enumerate(scatter_pairs):
    sns.scatterplot(
        data=main_df,
        x=col_x,
        y=col_y,
        hue='OutletType',
        ax=axes[i],
        alpha=0.7,
        s=30
    )
    axes[i].set_title(f'{col_y} vs {col_x}', fontsize=14)
    axes[i].grid(True, linestyle='--', alpha=0.5)

# remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])


plt.tight_layout(pad=3.0, h_pad=3, w_pad=5)
plt.show()

# %% [markdown]
# #### Analysis & Insights from Each Plot
#
# 1. `OutletSales_log vs MRP`
#
# Obeservations:
# - Strong positive trend: As MRP increases, sales generally increase — especially for Supermarket Type1/2/3.
# - Grocery Store (green): Lower sales across all price points — consistent with earlier boxplots.
# - Clustering: Sales are concentrated at certain MRP levels (e.g., 50, 100, 150) — likely due to pricing strategies.
#
# Insight:
# - MRP is a strong predictor of sales, and its effect varies by outlet type.
#
# 2. `OutletSales_log vs Visibility_log`
#
# Observations:
# - Weak positive trend: Higher visibility tends to correlate with higher sales.
# - Grocery Store (green): Many items have zero visibility (log=0) and low sales — confirms your IsVisibile flag is useful.
# - Supermarket Type3 (red): Has some high-visibility items with very high sales — may be premium or promotional.
#
# Insight:
# - Visibility matters, but the relationship is noisy and weak — best captured by your binary flag.
#
# 3. `OutletSales_log vs ItemWeight`
#
# Observations:
# - No clear pattern: Points are scattered randomly — no visible correlation.
# - All outlet types show similar randomness.
#
# Insight:
# - Item weight has little to no predictive power on sales.

# %% [markdown]
# ### Faceted Plots for multi-dimensional relationships

# %%
# Create faceted plot: MRP vs OutletSales_log, faceted by OutletType, colored by LocationType
g = sns.relplot(
    data=main_df,
    x='MRP',
    y='OutletSales_log',
    col='OutletType',                       # Facet by outlet type
    hue='LocationType',                     # Color by location tier
    col_wrap=2,                             # 2 columns per row
    height=4,                               # Height of each subplot
    aspect=1.2,                             # Width = height * aspect
    alpha=0.7,                              # Transparency for better visibility
    s=40,                                   # Marker size
    palette='magma',                          # Color palette for LocationType
)

# Customize titles and labels
g.set_titles("{col_name}")
g.set_axis_labels("MRP", "OutletSales_log")

# Add grid for better readability
for ax in g.axes.flat:
    ax.grid(True, linestyle='--', alpha=0.5)

# Adjust layout to prevent overlap
g.fig.suptitle('Faceted Scatter Plot For MRP vs OutletSales_log by OutletType & LocationType', fontsize=16, y=0.98)
g.fig.tight_layout(rect=[0, 0, 0.90, 0.96], h_pad=3)

# Show plot
plt.show()

# %% [markdown]
# #### Analysis & Insights from Each Plot
#
# 1. `Supermarket Type1`
#
# Obeservations:
# - Strong positive trend: As MRP increases, sales increase — especially clear for Tier 1 & 2.
# - Tier 3 (orange): Slightly lower sales at same MRP compared to Tier 1/2 — suggests lower purchasing power in Tier 3.
# - Clustering: Sales are concentrated at certain MRP levels (e.g., 50, 100, 150) — likely due to pricing strategies.
#
# Insight:
# - MRP is a strong predictor of sales in Supermarket Type1, and location tier matters.
#
# 2. `Supermarket Type2`
#
# Observations:
# - Weaker trend: Less clear relationship between MRP and sales.
# - No color separation: All location tiers (Tier 1, 2, 3) are mixed — suggests location doesn’t strongly affect sales here.
# - Sales range: Narrower than Type1 — may indicate smaller or more uniform stores.
#
# Insight:
# - MRP still matters, but less so than in Type1, and location tier is less predictive.
#
# 3. `Grocery Store`
#
# Observations:
# - Weak trend: Some positive correlation, but much noisier than Supermarkets.
# - Tier 1 (green): Higher sales at same MRP compared to Tier 2/3 — suggests Tier 1 Grocery Stores perform better.
# - Low sales overall: Confirms earlier boxplots — Grocery Stores have lower sales.
#
# Insight:
# - MRP has limited predictive power in Grocery Stores, but location tier still matters.
#
# 4. `Supermarket Type3`
#
# Observations:
# - Strongest trend: Clear positive relationship between MRP and sales.
# - All points are orange (Tier 3): No other location tiers present — suggests Type3 stores are only in Tier 3 areas.
# - High sales: Consistent with earlier boxplots — Type3 has highest median sales.
#
# Insight:
# - MRP is very predictive in Type3, and location tier is fixed

# %% [markdown]
# ### Action according to analysis

# %%
# Create IsGroceryStore flag
main_df['IsGroceryStore'] = (main_df['OutletType'] == 'Grocery Store').astype(int)

main_df.head()
# Out:
#    ItemWeight FatContent  Visibility               ItemType       MRP  \
# 0        9.30    Low Fat    0.016047                  Dairy  249.8092
# 1        5.92    Regular    0.019278            Soft Drinks   48.2692
# 2       17.50    Low Fat    0.016760                   Meat  141.6180
# 3       19.20    Regular    0.000000  Fruits and Vegetables  182.0950
# 4        8.93    Low Fat    0.000000              Household   53.8614
#
#   OutletSize LocationType         OutletType  OutletSales  OutletAge  \
# 0     Medium       Tier 1  Supermarket Type1    3735.1380         26
# 1     Medium       Tier 3  Supermarket Type2     443.4228         16
# 2     Medium       Tier 1  Supermarket Type1    2097.2700         26
# 3      Small       Tier 3      Grocery Store     732.3800         27
# 4       High       Tier 3  Supermarket Type1     994.7052         38
#
#    OutletSales_log  Visibility_log  IsVisibile  IsGroceryStore
# 0         8.225540        0.015920           1               0
# ...

# %% [markdown]
# ### Heatmap of Correlation Matrix

# %%
num_ft = main_df.select_dtypes(include='number')
num_ft = num_ft.drop(columns=['OutletSales'])

# %%
len(main_df.select_dtypes(include='number').columns)
# Out:
# 9

# %%
num_ft = main_df.select_dtypes(include='number')
num_ft = num_ft.drop(columns=['OutletSales'])

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(num_ft.corr(), annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Correlation Matrix - Numerical Features', fontsize=16, y=1.05)
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# #### Analysis & Insights from Each Plot
#
# 1. **Strongest Correlations (Positive & Negative)**
#
# | Pair                                 | Correlation   | Meaning                                                                                            |
# |:-------------------------------------|:--------------|:---------------------------------------------------------------------------------------------------|
# | `MRP` ↔ `OutletSales_log`            | +0.51         | Strongest positive predictor — higher price → higher sales (as expected in retail).                |
# | `IsGroceryStore` ↔ `OutletSales_log` | –0.66         | Strongest negative correlation — Grocery Stores have significantly lower sales than other outlets. |
# | `Visibility` ↔ `IsVisibile`          | +0.33         | Moderate positive — items with visibility are more likely to be flagged as “visible”.              |
# | `Visibility_log` ↔ `IsVisibile`      | +0.34         | Slightly stronger than raw Visibility — log version better captures the binary signal.             |
#
# ---
#
# 2. **Lowest / Weakest Correlations**
#
# | Pair                            | Correlation    | Meaning                                                                    |
# |:--------------------------------|:---------------|:---------------------------------------------------------------------------|
# | `ItemWeight` ↔ All others       | ~0.00 to ±0.03 | No meaningful relationship — weight doesn’t predict sales.                 |
# | `OutletAge` ↔ `OutletSales_log` | –0.08          | Very weak negative — older stores don’t consistently sell more or less.    |
# | `IsVisibile` ↔ `IsGroceryStore` | +0.01          | No relationship — whether an item is visible doesn’t depend on store type. |
#
# ---
#
# 3.  **Highly Correlated Pairs (Redundancy Check)**
#
# | Pair                            | Correlation   | Action                                                                                         |
# |:--------------------------------|:--------------|:-----------------------------------------------------------------------------------------------|
# | `Visibility` ↔ `Visibility_log` | +1.00         | ❗ Perfect correlation — they’re identical! This is a data leakage or redundant feature.       |
# | `IsVisibile` ↔ `Visibility_log` | +0.34         | Moderate — both capture visibility, but differently (binary vs continuous). Safe to keep both. |
# | `MRP` ↔ `Visibility_log`        | –0.00         | No relationship — pricing and display are independent.                                         |

# %% [markdown]
# ### Action according to analysis

# %%
main_df.columns
# Out:
# Index(['ItemWeight', 'FatContent', 'Visibility', 'ItemType', 'MRP',
#        'OutletSize', 'LocationType', 'OutletType', 'OutletSales', 'OutletAge',
#        'OutletSales_log', 'Visibility_log', 'IsVisibile', 'IsGroceryStore'],
#       dtype='object')

# %%
# drop redundant and unnecessary features
cols_to_drop = [
    'OutletSales',
    'Visibility',
]

# drop the columns
df = main_df.drop(columns=cols_to_drop)

# %%
# Verify final feature set
print("Final numerical features:")
print(df.select_dtypes(include="number").columns.to_list())

print("\nFinal categorical features:")
print(df.select_dtypes(include="object").columns.to_list())

print(f"\n📊 Final dataset shape: {df.shape}")
# Out:
# Final numerical features:
# ['ItemWeight', 'MRP', 'OutletAge', 'OutletSales_log', 'Visibility_log', 'IsVisibile', 'IsGroceryStore']
#
# Final categorical features:
# ['FatContent', 'ItemType', 'OutletSize', 'LocationType', 'OutletType']
#
# 📊 Final dataset shape: (8523, 12)

# %% [markdown]
# # Handling Missing Values

# %%
# check missing values
df.isnull().sum()
# Out:
# ItemWeight         1463
# FatContent            0
# ItemType              0
# MRP                   0
# OutletSize            0
# LocationType          0
# OutletType            0
# OutletAge             0
# OutletSales_log       0
# Visibility_log        0
# IsVisibile            0
# IsGroceryStore        0
# dtype: int64

# %%
# Impute missing ItemWeight using median weight per ItemType
df['ItemWeight'] = df.groupby('ItemType')['ItemWeight'].transform(
    lambda x: x.fillna(x.median())
)

# Verify no missing values remain
print("Missing values after imputation:")
print(df[['ItemWeight']].isnull().sum())
# Out:
# Missing values after imputation:
# ItemWeight    0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
# Standardize features names
df.rename(columns={
    "OutletSales_log": "OutletSales",
    "Visibility_log" : "Visibility"
}, inplace=True)

# remove leading and trailing spaces from column names
df.columns = df.columns.str.strip()

df.columns
# Out:
# Index(['ItemWeight', 'FatContent', 'ItemType', 'MRP', 'OutletSize',
#        'LocationType', 'OutletType', 'OutletAge', 'OutletSales', 'Visibility',
#        'IsVisibile', 'IsGroceryStore'],
#       dtype='object')

# %%
# compute price per unit weight — a strong signal in retail
df['PricePerWeight'] = df['MRP'] / df['ItemWeight']

# %% [markdown]
# # Categorial Encoding

# %%
# make a copy to avoid the modifying the original dataset
df_final = df.copy()

# define features
target = 'OutletSales'
categorical_features = df_final.select_dtypes(include='object').columns.tolist()
numerical_features = df_final.select_dtypes(include='number').columns.tolist()
numerical_features = [col for col in numerical_features if col != target]

# %% [markdown]
# **NOTE:** `numerical_features` contains only predictors, not the target. Now `x_train[numerical_features]` works because `x_train` and `numerical_features` are aligned

# %%
# split data to avoid target leakage
x = df_final.drop(columns=[target])
y = df_final[target]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# target encode for ItemType on train set only
target_encoder = TargetEncoder(cols=['ItemType'])

x_train_encoded = target_encoder.fit_transform(x_train[categorical_features], y_train)
x_test_encoded = target_encoder.transform(x_test[categorical_features])

# %%
# one hot encoding low-cardinality features
onehot_features = ['FatContent', 'OutletSize', 'LocationType', 'OutletType']
ohe = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')

# %%
# fit on train set
x_train_ohe = ohe.fit_transform(x_train[onehot_features])
x_test_ohe = ohe.transform(x_test[onehot_features])

# %%
# get feature names for OHE
ohe_feature_names = ohe.get_feature_names_out(onehot_features)

# %%
# convert to dataFrame
x_train_df = pd.DataFrame(x_train_ohe, columns=ohe_feature_names, index=x_train.index)
x_test_df = pd.DataFrame(x_test_ohe, columns=ohe_feature_names, index=x_test.index)

# %%
# combine numerical + encoded features
x_train_final = pd.concat([
    x_train[numerical_features].reset_index(drop=True),
    x_train_encoded[['ItemType']].reset_index(drop=True),
    x_train_df.reset_index(drop=True)
], axis=1)

x_test_final = pd.concat([
    x_test[numerical_features].reset_index(drop=True),
    x_test_encoded[['ItemType']].reset_index(drop=True),
    x_test_df.reset_index(drop=True)
], axis=1)

# %%
# reset y index to match
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
# shape of train and test set
print(f"Train shape: {x_train_final.shape}")
print(f"Test shape: {x_test_final.shape}")
# Out:
# Train shape: (6818, 16)
# Test shape: (1705, 16)

# %%
# feature scaling
scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train_final)
x_test_scale = scaler.transform(x_test_final)

# %%
# cross validation setup
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Save Artifacts

# %%
# directories
DATA_DIR = Path("../data")
ARTIFACTS_DIR = Path("../artifacts/feature-selection")

DATA_DIR.mkdir(parents=True, exist_ok=True)
ARTIFACTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
# save clean dataset before encoding
df_final.to_csv(DATA_DIR / "clean_dataset.csv", index=False)
print(f"✅ Saved clean dataset to {DATA_DIR / 'clean_dataset.csv'}")
# Out:
# ✅ Saved clean dataset to ..\data\clean_dataset.csv

# %%
# concatenate encoded  train and test data
encoded_full_train = pd.concat([x_train_final, y_train], axis=1)
encoded_full_test = pd.concat([x_test_final, y_test], axis=1)
encoded_dataset = pd.concat([encoded_full_train, encoded_full_test], ignore_index=True)

# %%
# save encoded dataset
encoded_dataset.to_csv(DATA_DIR / "encoded_dataset.csv", index=False)
print(f"✅ Saved single encoded dataset to {DATA_DIR / 'encoded_dataset.csv'}")
# Out:
# ✅ Saved single encoded dataset to ..\data\encoded_dataset.csv

# %%
# Save all artifacts
joblib.dump(x_train_final, ARTIFACTS_DIR / "x_train.pkl")
joblib.dump(x_test_final, ARTIFACTS_DIR / "x_test.pkl")
joblib.dump(y_train, ARTIFACTS_DIR / "y_train.pkl")
joblib.dump(y_test, ARTIFACTS_DIR / "y_test.pkl")
joblib.dump(cv, ARTIFACTS_DIR / "cv.pkl")
joblib.dump(x_train_scale, ARTIFACTS_DIR / "x_train_scale.pkl")
joblib.dump(x_test_scale, ARTIFACTS_DIR / "x_test_scale.pkl")

print(f"✅ Saved artifacts to {ARTIFACTS_DIR / ''}")
# Out:
# ✅ Saved artifacts to ..\artifacts\feature-selection
